# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_json('json1.json', convert_dates=False, orient='split')

# %%
data.Responses[0][0]['lines'][0]['vehiclePositions']
# Out:
# [{'directionId': '8161', 'distanceFromPoint': 1, 'pointId': '8012'},
#  {'directionId': '8162', 'distanceFromPoint': 0, 'pointId': '8142'},
#  {'directionId': '8162', 'distanceFromPoint': 0, 'pointId': '8282'},
#  {'directionId': '8731', 'distanceFromPoint': 0, 'pointId': '8111'},
#  {'directionId': '8162', 'distanceFromPoint': 1, 'pointId': '8062'},
#  {'directionId': '8731', 'distanceFromPoint': 0, 'pointId': '8281'},
#  {'directionId': '8161', 'distanceFromPoint': 1, 'pointId': '8102'},
#  {'directionId': '8731', 'distanceFromPoint': 0, 'pointId': '8162'},
#  {'directionId': '8731', 'distanceFromPoint': 0, 'pointId': '8151'},
#  {'directionId': '8731', 'distanceFromPoint': 1, 'pointId': '8081'},
#  {'directionId': '8161', 'distanceFromPoint': 0, 'pointId': '8733'},
#  {'directionId': '8731', 'distanceFromPoint': 0, 'pointId': '8741'},
#  {'directionId': '8731', 'distanceFromPoint': 0, 'pointId': '8041'}]

# %%
data_line1 = []
index = []

for i in range(len(data)-1):
    try:
        data_line1.append(data.Responses[i][0]['lines'][0]['vehiclePositions'])
    except:
        index.append(i)
        pass

# %%
data_line1
# Out:
# [[{'directionId': '8161', 'distanceFromPoint': 1, 'pointId': '8012'},
#   {'directionId': '8162', 'distanceFromPoint': 0, 'pointId': '8142'},
#   {'directionId': '8162', 'distanceFromPoint': 0, 'pointId': '8282'},
#   {'directionId': '8731', 'distanceFromPoint': 0, 'pointId': '8111'},
#   {'directionId': '8162', 'distanceFromPoint': 1, 'pointId': '8062'},
#   {'directionId': '8731', 'distanceFromPoint': 0, 'pointId': '8281'},
#   {'directionId': '8161', 'distanceFromPoint': 1, 'pointId': '8102'},
#   {'directionId': '8731', 'distanceFromPoint': 0, 'pointId': '8162'},
#   {'directionId': '8731', 'distanceFromPoint': 0, 'pointId': '8151'},
#   {'directionId': '8731', 'distanceFromPoint': 1, 'pointId': '8081'},
#   {'directionId': '8161', 'distanceFromPoint': 0, 'pointId': '8733'},
#   {'directionId': '8731', 'distanceFromPoint': 0, 'pointId': '8741'},
#   {'directionId': '8731', 'distanceFromPoint': 0, 'pointId': '8041'}],
# ...

# %%
index
# Out:
# [1784,
#  1786,
#  1789,
#  1790,
#  1795,
#  1797,
#  1799,
#  1804,
#  1806,
#  1812,
#  1813,
#  1815,
#  1816,
#  1817,
#  1819,
#  1820,
#  1822,
#  1823,
#  1825,
#  1826,
#  1833,
#  1834,
#  1836,
#  1837,
#  1838,
#  1844,
#  1845,
#  1846,
#  1853,
#  1855,
#  1856,
#  1857,
#  1863,
#  1864,
#  1868,
#  1872,
#  1873,
#  1875,
#  1880,
#  1881,
#  1883,
#  1893,
#  1894,
#  1897,
#  1898,
#  1902,
#  1903,
#  1905,
#  1907,
#  1908,
#  1909,
#  1912,
#  1913,
#  1916,
#  1919,
#  1920,
#  1921,
#  1922,
#  1924,
#  1926,
#  1927,
#  1928,
#  1929,
#  1932,
#  1935,
#  1939,
#  1940,
#  1941,
#  1949,
#  1950,
#  1952,
#  1954,
#  1957,
#  1963,
#  1965,
#  1967,
#  1968,
#  1973,
#  1974,
#  1977,
#  1978,
#  1981,
#  1983,
#  1988,
#  1989,
#  1992,
#  1993,
#  1995,
#  1997,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2007,
#  2008,
#  2011,
#  2013,
#  2014,
#  2016,
#  2017,
#  2018,
#  2019,
#  2021,
#  2023,
#  2024,
#  2026,
#  2028,
#  2030,
#  2031,
#  2032,
# ...

# %%
data.Responses[1822]
# Out:
# [{'lines': []},
#  {'lines': [{'lineId': '14',
#     'vehiclePositions': [{'directionId': '4265',
#       'distanceFromPoint': 158,
#       'pointId': '4268'},
#      {'directionId': '4265', 'distanceFromPoint': 56, 'pointId': '2873'},
#      {'directionId': '4265', 'distanceFromPoint': 182, 'pointId': '5076'},
#      {'directionId': '1722', 'distanceFromPoint': 87, 'pointId': '7062'},
#      {'directionId': '1722', 'distanceFromPoint': 0, 'pointId': '4264'}]},
#    {'lineId': '19',
#     'vehiclePositions': [{'directionId': '5170',
#       'distanceFromPoint': 232,
#       'pointId': '5166'}]}]},
#  {'lines': [{'lineId': '36',
#     'vehiclePositions': [{'directionId': '1148',
#       'distanceFromPoint': 171,
#       'pointId': '1846'},
#      {'directionId': '1148', 'distanceFromPoint': 615, 'pointId': '1859'}]}]},
#  {'lines': [{'lineId': '45',
#     'vehiclePositions': [{'directionId': '9292',
#       'distanceFromPoint': 34,
#       'pointId': '1525'},
# ...
